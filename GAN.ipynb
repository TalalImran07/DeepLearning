# %% [markdown]
# <a href="https://colab.research.google.com/github/TalalImran07/DeepLearning/blob/main/GAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import Required Libraries

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
import numpy as np

# Set device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# Defining a Transform

# %%
# Define a basic transform
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# %% [markdown]
# Loading the Dataset

# %%
train_dataset = datasets.CIFAR10(root='./data',\
              train=True, download=True, transform=transform)
dataloader = torch.utils.data.DataLoader(train_dataset, \
                                batch_size=32, shuffle=True)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:04<00:00, 36353599.35it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data

# %% [markdown]
# Defininf Parameters to be used in later process

# %%
# Hyperparameters
latent_dim = 100
lr = 0.0002
beta1 = 0.5
beta2 = 0.999
num_epochs = 10

# %% [markdown]
# Building a Class for the Generator

# %%
# Define the generator
class Generator(nn.Module):
    def __init__(self, latent_dim):
        super(Generator, self).__init__()

        self.model = nn.Sequential(
            nn.Linear(latent_dim, 128 * 8 * 8),
            nn.ReLU(),
            nn.Unflatten(1, (128, 8, 8)),
            nn.Upsample(scale_factor=2),
            nn.Conv2d(128, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128, momentum=0.78),
            nn.ReLU(),
            nn.Upsample(scale_factor=2),
            nn.Conv2d(128, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64, momentum=0.78),
            nn.ReLU(),
            nn.Conv2d(64, 3, kernel_size=3, padding=1),
            nn.Tanh()
        )

    def forward(self, z):
        img = self.model(z)
        return img

# %% [markdown]
# Building a Discriminator

# %%
# Define the discriminator
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()

        self.model = nn.Sequential(
        nn.Conv2d(3, 32, kernel_size=3, stride=2, padding=1),
        nn.LeakyReLU(0.2),
        nn.Dropout(0.25),
        nn.Conv2d(32, 64, kernel_size=3, stride=2, padding=1),
        nn.ZeroPad2d((0, 1, 0, 1)),
        nn.BatchNorm2d(64, momentum=0.82),
        nn.LeakyReLU(0.25),
        nn.Dropout(0.25),
        nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1),
        nn.BatchNorm2d(128, momentum=0.82),
        nn.LeakyReLU(0.2),
        nn.Dropout(0.25),
        nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1),
        nn.BatchNorm2d(256, momentum=0.8),
        nn.LeakyReLU(0.25),
        nn.Dropout(0.25),
        nn.Flatten(),
        nn.Linear(256 * 5 * 5, 1),
        nn.Sigmoid()
    )

    def forward(self, img):
        validity = self.model(img)
        return validity

# %% [markdown]
# Building the GAN

# %%
# Define the generator and discriminator
# Initialize generator and discriminator
generator = Generator(latent_dim).to(device)
discriminator = Discriminator().to(device)
# Loss function
adversarial_loss = nn.BCELoss()
# Optimizers
optimizer_G = optim.Adam(generator.parameters()\
                         , lr=lr, betas=(beta1, beta2))
optimizer_D = optim.Adam(discriminator.parameters()\
                         , lr=lr, betas=(beta1, beta2))

# %% [markdown]
# Train the GAN

# %%
# Training loop
for epoch in range(num_epochs):
    for i, batch in enumerate(dataloader):
       # Convert list to tensor
        real_images = batch[0].to(device)
        # Adversarial ground truths
        valid = torch.ones(real_images.size(0), 1, device=device)
        fake = torch.zeros(real_images.size(0), 1, device=device)
        # Configure input
        real_images = real_images.to(device)

        # ---------------------
        #  Train Discriminator
        # ---------------------
        optimizer_D.zero_grad()
        # Sample noise as generator input
        z = torch.randn(real_images.size(0), latent_dim, device=device)
        # Generate a batch of images
        fake_images = generator(z)

        # Measure discriminator's ability
        # to classify real and fake images
        real_loss = adversarial_loss(discriminator\
                                     (real_images), valid)
        fake_loss = adversarial_loss(discriminator\
                                     (fake_images.detach()), fake)
        d_loss = (real_loss + fake_loss) / 2
        # Backward pass and optimize
        d_loss.backward()
        optimizer_D.step()

        # -----------------
        #  Train Generator
        # -----------------

        optimizer_G.zero_grad()
        # Generate a batch of images
        gen_images = generator(z)
        # Adversarial loss
        g_loss = adversarial_loss(discriminator(gen_images), valid)
        # Backward pass and optimize
        g_loss.backward()
        optimizer_G.step()
        # ---------------------
        #  Progress Monitoring
        # ---------------------
        if (i + 1) % 100 == 0:
            print(
                f"Epoch [{epoch+1}/{num_epochs}]\
                        Batch {i+1}/{len(dataloader)} "
                f"Discriminator Loss: {d_loss.item():.4f} "
                f"Generator Loss: {g_loss.item():.4f}"
            )
    # Save generated images for every epoch
    if (epoch + 1) % 10 == 0:
        with torch.no_grad():
            z = torch.randn(16, latent_dim, device=device)
            generated = generator(z).detach().cpu()
            grid = torchvision.utils.make_grid(generated,\
                                        nrow=4, normalize=True)
            plt.imshow(np.transpose(grid, (1, 2, 0)))
            plt.axis("off")
            plt.show()
# Out:
# Epoch [1/10]                        Batch 100/1563 Discriminator Loss: 0.5001 Generator Loss: 1.8203
# Epoch [1/10]                        Batch 200/1563 Discriminator Loss: 0.6958 Generator Loss: 1.0098
# Epoch [1/10]                        Batch 300/1563 Discriminator Loss: 0.6241 Generator Loss: 1.0362
# Epoch [1/10]                        Batch 400/1563 Discriminator Loss: 0.7300 Generator Loss: 1.2117
# Epoch [1/10]                        Batch 500/1563 Discriminator Loss: 0.5919 Generator Loss: 1.2039
# Epoch [1/10]                        Batch 600/1563 Discriminator Loss: 0.5574 Generator Loss: 0.9827
# Epoch [1/10]                        Batch 700/1563 Discriminator Loss: 0.7284 Generator Loss: 1.0897
# Epoch [1/10]                        Batch 800/1563 Discriminator Loss: 0.7918 Generator Loss: 0.8000
# Epoch [1/10]                        Batch 900/1563 Discriminator Loss: 0.7740 Generator Loss: 0.7120
# Epoch [1/10]                        Batch 1000/1563 Discriminator Loss: 0.8128 Generator Loss: 0.7793
# Epoch [1/10]                        Batch 1100/1563 Discriminator Loss: 0.6011 Generator Loss: 0.9246
# Epoch [1/10]                        Batch 1200/1563 Discriminator Loss: 0.5799 Generator Loss: 1.0109
# Epoch [1/10]                        Batch 1300/1563 Discriminator Loss: 0.7592 Generator Loss: 0.8347
# Epoch [1/10]                        Batch 1400/1563 Discriminator Loss: 0.6023 Generator Loss: 1.0124
# Epoch [1/10]                        Batch 1500/1563 Discriminator Loss: 0.6333 Generator Loss: 0.9265
# Epoch [2/10]                        Batch 100/1563 Discriminator Loss: 0.7760 Generator Loss: 0.6920
# Epoch [2/10]                        Batch 200/1563 Discriminator Loss: 0.6399 Generator Loss: 0.9953
# Epoch [2/10]                        Batch 300/1563 Discriminator Loss: 0.6568 Generator Loss: 0.8779
# Epoch [2/10]                        Batch 400/1563 Discriminator Loss: 0.7123 Generator Loss: 0.6781
# Epoch [2/10]                        Batch 500/1563 Discriminator Loss: 0.5788 Generator Loss: 1.4281
# Epoch [2/10]                        Batch 600/1563 Discriminator Loss: 0.7641 Generator Loss: 1.2228
# Epoch [2/10]                        Batch 700/1563 Discriminator Loss: 0.6109 Generator Loss: 0.9018
# Epoch [2/10]                        Batch 800/1563 Discriminator Loss: 0.7977 Generator Loss: 0.7560
# Epoch [2/10]                        Batch 900/1563 Discriminator Loss: 0.6313 Generator Loss: 1.1483
# Epoch [2/10]                        Batch 1000/1563 Discriminator Loss: 0.5408 Generator Loss: 0.7424
# Epoch [2/10]                        Batch 1100/1563 Discriminator Loss: 0.4748 Generator Loss: 1.4222
# Epoch [2/10]                        Batch 1200/1563 Discriminator Loss: 0.6117 Generator Loss: 1.0810
# Epoch [2/10]                        Batch 1300/1563 Discriminator Loss: 0.6616 Generator Loss: 0.8606
# Epoch [2/10]                        Batch 1400/1563 Discriminator Loss: 0.5386 Generator Loss: 1.2789
# Epoch [2/10]                        Batch 1500/1563 Discriminator Loss: 0.6383 Generator Loss: 1.3780
# Epoch [3/10]                        Batch 100/1563 Discriminator Loss: 0.5536 Generator Loss: 1.2453
# Epoch [3/10]                        Batch 200/1563 Discriminator Loss: 0.5289 Generator Loss: 1.0346
# Epoch [3/10]                        Batch 300/1563 Discriminator Loss: 0.6052 Generator Loss: 0.9122
# Epoch [3/10]                        Batch 400/1563 Discriminator Loss: 0.6126 Generator Loss: 0.8895
# Epoch [3/10]                        Batch 500/1563 Discriminator Loss: 0.6002 Generator Loss: 0.9520
# Epoch [3/10]                        Batch 600/1563 Discriminator Loss: 0.5199 Generator Loss: 0.9110
# Epoch [3/10]                        Batch 700/1563 Discriminator Loss: 0.6624 Generator Loss: 1.0153
# Epoch [3/10]                        Batch 800/1563 Discriminator Loss: 0.5464 Generator Loss: 1.1630
# Epoch [3/10]                        Batch 900/1563 Discriminator Loss: 0.7491 Generator Loss: 1.0190
# Epoch [3/10]                        Batch 1000/1563 Discriminator Loss: 0.5140 Generator Loss: 1.2465
# Epoch [3/10]                        Batch 1100/1563 Discriminator Loss: 0.5431 Generator Loss: 1.3261
# Epoch [3/10]                        Batch 1200/1563 Discriminator Loss: 0.7634 Generator Loss: 1.1592
# Epoch [3/10]                        Batch 1300/1563 Discriminator Loss: 0.6217 Generator Loss: 1.2042
# Epoch [3/10]                        Batch 1400/1563 Discriminator Loss: 0.5204 Generator Loss: 1.1683
# Epoch [3/10]                        Batch 1500/1563 Discriminator Loss: 0.5213 Generator Loss: 0.9330
# Epoch [4/10]                        Batch 100/1563 Discriminator Loss: 0.5845 Generator Loss: 1.2183
# Epoch [4/10]                        Batch 200/1563 Discriminator Loss: 0.7541 Generator Loss: 0.7016
# Epoch [4/10]                        Batch 300/1563 Discriminator Loss: 0.6038 Generator Loss: 1.2386
# Epoch [4/10]                        Batch 400/1563 Discriminator Loss: 0.4364 Generator Loss: 0.9542
# Epoch [4/10]                        Batch 500/1563 Discriminator Loss: 0.6446 Generator Loss: 0.9873
# Epoch [4/10]                        Batch 600/1563 Discriminator Loss: 0.6274 Generator Loss: 1.1960
# Epoch [4/10]                        Batch 700/1563 Discriminator Loss: 0.6827 Generator Loss: 1.0869
# Epoch [4/10]                        Batch 800/1563 Discriminator Loss: 0.5691 Generator Loss: 1.4904
# Epoch [4/10]                        Batch 900/1563 Discriminator Loss: 0.4345 Generator Loss: 1.5689
# Epoch [4/10]                        Batch 1000/1563 Discriminator Loss: 0.4501 Generator Loss: 1.1572
# Epoch [4/10]                        Batch 1100/1563 Discriminator Loss: 0.7730 Generator Loss: 1.1456
# Epoch [4/10]                        Batch 1200/1563 Discriminator Loss: 0.5917 Generator Loss: 1.5549
# Epoch [4/10]                        Batch 1300/1563 Discriminator Loss: 0.7019 Generator Loss: 1.2856
# Epoch [4/10]                        Batch 1400/1563 Discriminator Loss: 0.5229 Generator Loss: 1.6543
# Epoch [4/10]                        Batch 1500/1563 Discriminator Loss: 0.6550 Generator Loss: 1.3001
# Epoch [5/10]                        Batch 100/1563 Discriminator Loss: 0.5167 Generator Loss: 1.3214
# Epoch [5/10]                        Batch 200/1563 Discriminator Loss: 0.4942 Generator Loss: 1.0439
# Epoch [5/10]                        Batch 300/1563 Discriminator Loss: 0.4964 Generator Loss: 1.1832
# Epoch [5/10]                        Batch 400/1563 Discriminator Loss: 1.3664 Generator Loss: 1.2829
# Epoch [5/10]                        Batch 500/1563 Discriminator Loss: 0.4757 Generator Loss: 1.2977
# Epoch [5/10]                        Batch 600/1563 Discriminator Loss: 0.5285 Generator Loss: 1.5146
# Epoch [5/10]                        Batch 700/1563 Discriminator Loss: 0.4479 Generator Loss: 1.1948
# Epoch [5/10]                        Batch 800/1563 Discriminator Loss: 0.5691 Generator Loss: 1.2510
# Epoch [5/10]                        Batch 900/1563 Discriminator Loss: 0.4682 Generator Loss: 1.2103
# Epoch [5/10]                        Batch 1000/1563 Discriminator Loss: 0.6386 Generator Loss: 0.8869
# Epoch [5/10]                        Batch 1100/1563 Discriminator Loss: 0.8617 Generator Loss: 1.2767
# Epoch [5/10]                        Batch 1200/1563 Discriminator Loss: 0.6084 Generator Loss: 0.8601
# Epoch [5/10]                        Batch 1300/1563 Discriminator Loss: 0.4897 Generator Loss: 1.3166
# Epoch [5/10]                        Batch 1400/1563 Discriminator Loss: 0.5966 Generator Loss: 1.7128
# Epoch [5/10]                        Batch 1500/1563 Discriminator Loss: 0.4184 Generator Loss: 1.7682
# Epoch [6/10]                        Batch 100/1563 Discriminator Loss: 0.6704 Generator Loss: 0.8172
# Epoch [6/10]                        Batch 200/1563 Discriminator Loss: 0.6204 Generator Loss: 1.2642
# Epoch [6/10]                        Batch 300/1563 Discriminator Loss: 0.4901 Generator Loss: 1.3737
# Epoch [6/10]                        Batch 400/1563 Discriminator Loss: 0.4420 Generator Loss: 1.2674
# Epoch [6/10]                        Batch 500/1563 Discriminator Loss: 0.4848 Generator Loss: 1.4076
# Epoch [6/10]                        Batch 600/1563 Discriminator Loss: 0.7479 Generator Loss: 0.8303
# Epoch [6/10]                        Batch 700/1563 Discriminator Loss: 0.6935 Generator Loss: 1.1865
# Epoch [6/10]                        Batch 800/1563 Discriminator Loss: 0.4939 Generator Loss: 1.1405
# Epoch [6/10]                        Batch 900/1563 Discriminator Loss: 0.7138 Generator Loss: 1.0218
# Epoch [6/10]                        Batch 1000/1563 Discriminator Loss: 0.4718 Generator Loss: 1.5797
# Epoch [6/10]                        Batch 1100/1563 Discriminator Loss: 0.6584 Generator Loss: 0.8894
# Epoch [6/10]                        Batch 1200/1563 Discriminator Loss: 0.3893 Generator Loss: 1.0790
# Epoch [6/10]                        Batch 1300/1563 Discriminator Loss: 0.5490 Generator Loss: 1.1169
# Epoch [6/10]                        Batch 1400/1563 Discriminator Loss: 0.4438 Generator Loss: 1.5160
# Epoch [6/10]                        Batch 1500/1563 Discriminator Loss: 0.3951 Generator Loss: 1.7780
# Epoch [7/10]                        Batch 100/1563 Discriminator Loss: 0.5230 Generator Loss: 1.4167
# Epoch [7/10]                        Batch 200/1563 Discriminator Loss: 0.5418 Generator Loss: 1.2936
# Epoch [7/10]                        Batch 300/1563 Discriminator Loss: 0.6323 Generator Loss: 0.9081
# Epoch [7/10]                        Batch 400/1563 Discriminator Loss: 0.4386 Generator Loss: 1.0193
# Epoch [7/10]                        Batch 500/1563 Discriminator Loss: 0.6655 Generator Loss: 1.3448
# Epoch [7/10]                        Batch 600/1563 Discriminator Loss: 0.5505 Generator Loss: 1.9361
# Epoch [7/10]                        Batch 700/1563 Discriminator Loss: 0.3891 Generator Loss: 1.9841
# Epoch [7/10]                        Batch 800/1563 Discriminator Loss: 0.7327 Generator Loss: 0.8519
# Epoch [7/10]                        Batch 900/1563 Discriminator Loss: 0.4408 Generator Loss: 1.1401
# Epoch [7/10]                        Batch 1000/1563 Discriminator Loss: 0.5762 Generator Loss: 1.2321
# Epoch [7/10]                        Batch 1100/1563 Discriminator Loss: 0.5860 Generator Loss: 1.0888
# Epoch [7/10]                        Batch 1200/1563 Discriminator Loss: 0.3613 Generator Loss: 1.2467
# Epoch [7/10]                        Batch 1300/1563 Discriminator Loss: 0.4477 Generator Loss: 1.1773
# Epoch [7/10]                        Batch 1400/1563 Discriminator Loss: 0.6111 Generator Loss: 1.6684
# Epoch [7/10]                        Batch 1500/1563 Discriminator Loss: 0.3651 Generator Loss: 1.2715
# Epoch [8/10]                        Batch 100/1563 Discriminator Loss: 0.5734 Generator Loss: 1.3199
# Epoch [8/10]                        Batch 200/1563 Discriminator Loss: 0.4173 Generator Loss: 1.7013
# Epoch [8/10]                        Batch 300/1563 Discriminator Loss: 0.3793 Generator Loss: 1.0748
# Epoch [8/10]                        Batch 400/1563 Discriminator Loss: 0.7623 Generator Loss: 0.8611
# Epoch [8/10]                        Batch 500/1563 Discriminator Loss: 0.4235 Generator Loss: 1.5698
# Epoch [8/10]                        Batch 600/1563 Discriminator Loss: 0.4774 Generator Loss: 1.1962
# Epoch [8/10]                        Batch 700/1563 Discriminator Loss: 0.4438 Generator Loss: 1.8530
# Epoch [8/10]                        Batch 800/1563 Discriminator Loss: 0.6029 Generator Loss: 1.5400
# Epoch [8/10]                        Batch 900/1563 Discriminator Loss: 0.8101 Generator Loss: 1.3424
# Epoch [8/10]                        Batch 1000/1563 Discriminator Loss: 0.7408 Generator Loss: 1.0086
# Epoch [8/10]                        Batch 1100/1563 Discriminator Loss: 0.7241 Generator Loss: 1.7057
# Epoch [8/10]                        Batch 1200/1563 Discriminator Loss: 0.3802 Generator Loss: 1.9371
# Epoch [8/10]                        Batch 1300/1563 Discriminator Loss: 0.5868 Generator Loss: 1.1188
# Epoch [8/10]                        Batch 1400/1563 Discriminator Loss: 0.4854 Generator Loss: 1.7221
# Epoch [8/10]                        Batch 1500/1563 Discriminator Loss: 0.3695 Generator Loss: 1.0342
# Epoch [9/10]                        Batch 100/1563 Discriminator Loss: 0.6697 Generator Loss: 0.9078
# Epoch [9/10]                        Batch 200/1563 Discriminator Loss: 0.5042 Generator Loss: 1.0624
# Epoch [9/10]                        Batch 300/1563 Discriminator Loss: 0.6127 Generator Loss: 1.1566
# Epoch [9/10]                        Batch 400/1563 Discriminator Loss: 0.4566 Generator Loss: 1.3573
# Epoch [9/10]                        Batch 500/1563 Discriminator Loss: 0.5230 Generator Loss: 1.1788
# Epoch [9/10]                        Batch 600/1563 Discriminator Loss: 0.3463 Generator Loss: 1.4838
# Epoch [9/10]                        Batch 700/1563 Discriminator Loss: 0.5301 Generator Loss: 1.4289
# Epoch [9/10]                        Batch 800/1563 Discriminator Loss: 0.6362 Generator Loss: 0.7493
# Epoch [9/10]                        Batch 900/1563 Discriminator Loss: 0.5675 Generator Loss: 1.2894
# Epoch [9/10]                        Batch 1000/1563 Discriminator Loss: 0.9325 Generator Loss: 0.9282
# Epoch [9/10]                        Batch 1100/1563 Discriminator Loss: 0.4396 Generator Loss: 1.4250
# Epoch [9/10]                        Batch 1200/1563 Discriminator Loss: 0.6615 Generator Loss: 1.0164
# Epoch [9/10]                        Batch 1300/1563 Discriminator Loss: 0.6922 Generator Loss: 0.5510
# Epoch [9/10]                        Batch 1400/1563 Discriminator Loss: 0.5450 Generator Loss: 1.1952
# Epoch [9/10]                        Batch 1500/1563 Discriminator Loss: 0.4905 Generator Loss: 1.3493
# Epoch [10/10]                        Batch 100/1563 Discriminator Loss: 0.3573 Generator Loss: 1.8286
# Epoch [10/10]                        Batch 200/1563 Discriminator Loss: 0.4759 Generator Loss: 0.8389
# Epoch [10/10]                        Batch 300/1563 Discriminator Loss: 0.5956 Generator Loss: 0.7619
# Epoch [10/10]                        Batch 400/1563 Discriminator Loss: 0.5543 Generator Loss: 1.0126
# Epoch [10/10]                        Batch 500/1563 Discriminator Loss: 0.4812 Generator Loss: 1.2824
# Epoch [10/10]                        Batch 600/1563 Discriminator Loss: 0.5912 Generator Loss: 2.0227
# Epoch [10/10]                        Batch 700/1563 Discriminator Loss: 0.5285 Generator Loss: 1.2932
# Epoch [10/10]                        Batch 800/1563 Discriminator Loss: 0.5821 Generator Loss: 1.2595
# Epoch [10/10]                        Batch 900/1563 Discriminator Loss: 0.6194 Generator Loss: 0.8720
# Epoch [10/10]                        Batch 1000/1563 Discriminator Loss: 0.6311 Generator Loss: 1.0203
# Epoch [10/10]                        Batch 1100/1563 Discriminator Loss: 0.5897 Generator Loss: 1.9948
# Epoch [10/10]                        Batch 1200/1563 Discriminator Loss: 0.5417 Generator Loss: 1.3249
# Epoch [10/10]                        Batch 1300/1563 Discriminator Loss: 0.3162 Generator Loss: 0.9540
# Epoch [10/10]                        Batch 1400/1563 Discriminator Loss: 0.6115 Generator Loss: 1.3927
# Epoch [10/10]                        Batch 1500/1563 Discriminator Loss: 0.5213 Generator Loss: 1.1924
